# %%
import SinglePython
import pandas as pd
import numpy as np
import utils
import scipy

# %%
refDataset = pd.read_csv("./Data/Reference/CHETAH/chetah_ref_data.csv", sep=";", decimal = ",", index_col = 0)
refDataset = refDataset.astype('float')

annot = pd.read_csv("./Data/Reference/CHETAH/chetah_ref_annot.csv",sep=";", index_col = 0)
annot.columns = ["level1"]

# %%
data =utils.readSCData("C:/Users/murat_gga8ya6/Desktop/Thesis/Datasets/Smart-Seq2/Melanoma/",200)
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
obj = SinglePython.SinglePythonObject(refDataset=refDataset,refAnnot=annot,scData=data,fine_tuning=True,tuning_by="threshold",multiProcess=True)

# %%
obj.annotateCellTypes()

# %%
result.final_annotations = result.final_annotations.T
result.final_annotations.columns = ["level1"]
cell_type = pd.read_csv("C:/Users/murat_gga8ya6/Desktop/Thesis/Datasets/Smart-Seq2/Melanoma/sc_annotations.csv",sep=",", index_col = 0)
cell_type.columns = ["original"]
result.final_annotations["original"] = cell_type["original"]

# %%
#result.final_annotations.to_csv("C:/Users/murat_gga8ya6/Desktop/Thesis/Validations/Melanoma/SinglePython_top_n/Melanoma_results.csv")

# %%
pd.DataFrame.from_csv("C:/Users/murat_gga8ya6/Desktop/sr.csv")
# Out:
# C:\Users\murat_gga8ya6\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
#                                 B cell  CD4 T cell  CD8 T cell  Dendritic  \
# Cy72_CD45_H02_S758_comb       0.233234    0.363260    0.305171   0.263001
# CY58_1_CD45_B02_S974_comb     0.241964    0.318277    0.333200   0.251923
# Cy72_CD45_D09_S717_comb       0.223466    0.374105    0.313741   0.239485
# Cy74_CD45_A03_S387_comb       0.217699    0.283855    0.313086   0.237370
# Cy74_CD45_F09_S453_comb       0.194026    0.321581    0.320924   0.209988
# CY58_1_CD45_D03_S999_comb     0.230138    0.370821    0.322922   0.258629
# Cy72_CD45_C01_S697_comb       0.199535    0.374186    0.302701   0.255002
# ...

# %%
obj.scData.obs
# Out:
#                                  n_counts  n_genes    cell_type
# Cy72_CD45_H02_S758_comb        56850008.0     3365   CD4 T cell
# CY58_1_CD45_B02_S974_comb      73959520.0     3637   CD8 T cell
# Cy72_CD45_D09_S717_comb        69143384.0     2826   CD4 T cell
# Cy74_CD45_A03_S387_comb        61800624.0     2563   CD8 T cell
# Cy74_CD45_F09_S453_comb        61283656.0     2682   CD4 T cell
# CY58_1_CD45_D03_S999_comb      69488224.0     3027   CD4 T cell
# Cy72_CD45_C01_S697_comb        41906112.0     2882   CD4 T cell
# Cy71_CD45_D07_S523_comb        98676616.0     3687   CD8 T cell
# Cy74_CD45_D04_S424_comb        57554964.0     2094   CD8 T cell
# Cy74_CD45_C11_S419_comb        61743332.0     2613   CD8 T cell
# Cy81_FNA_CD45_D07_S235_comb    60168416.0     3071   CD4 T cell
# Cy72_CD45_D07_S715_comb        64119232.0     2718   CD4 T cell
# Cy72_CD45_E08_S728_comb        75855944.0     2984   CD4 T cell
# Cy71_CD45_B07_S499_comb        75894776.0     2075   CD8 T cell
# ...

# %%
topn_multi : 1.32 min

# %%
topn_single : 3 min

# %%
thresh_multi : 1.50

# %%
thresh_single : 5.18

# %%
from multiprocessing import Pool
import multiP

p = Pool(5)
p.starmap(multiP.temp, [("asd","gre"),("ewer","reg")])
# Out:
# ['asdgre', 'ewerreg']
